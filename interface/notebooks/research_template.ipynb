# %% [markdown]
# # OpenLogic Finance - Research & Strategy Formulation Template
#
# Welcome to the **Notebook-as-a-Service** environment (Box 6: Interface).
#
# This notebook serves as a research playground to:
# 1. Connect with the `data_prep` layer to fetch historical and GDELT macro event data.
# 2. Invoke predictive filters from the `model_library` layer (e.g. Robust Gibbs Aggregator and stochastic filters).
# 3. Formulate signal thresholds before exporting them into `strategy_testing` (QuantConnect LEAN backtests).

# %%
# 1. Setup path to import OpenLogic Finance packages
import sys
import os

sys.path.append(os.path.abspath("../../"))

# Verify imports
print("✅ Core packages loaded successfully!")
